# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
# Importing the dataset
data = pd.read_csv('data.csv')
print(data.columns)
print("dimension of data: {}".format(data.shape))
data.info()
data.head()
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')
# dimension of data: (569, 33)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
# ...

# %%
# Getting the values and plotting it
f1 = data['Pregnancies'].values
f2 = data['Glucose'].values
f3 = data['BloodPressure'].values
f4 = data['Insulin'].values
f5 = data['BMI'].values
f6 = data['Age'].values
f7 = data['Outcome'].values



X = np.array(list(zip(f1, f2, f3, f4, f5, f6,f7)))

# %%
from sklearn.cluster import KMeans

# Number of clusters
kmeans = KMeans(n_clusters=4)
# Fitting the input data
kmeans = kmeans.fit(X)
# Getting the cluster labels
labels = kmeans.predict(X)
# Centroid values
centroids = kmeans.cluster_centers_

labels = kmeans.labels_

# %%
# Comparing with scikit-learn centroids

print(centroids) # From sci-kit learn
# Out:
# [[1.21197183e+02 1.23591549e+02 3.22105634e+01 3.52112676e-01]
#  [1.71230769e+02 5.62230769e+02 3.40076923e+01 6.15384615e-01]
#  [1.15829431e+02 9.37458194e+00 3.18123746e+01 3.27759197e-01]
#  [1.44369565e+02 2.74913043e+02 3.19847826e+01 5.65217391e-01]]

# %%
#print(labels)

colors = ["g.","r.","c.","y."]

for i in range(len(X)):
    print("coordinate:",X[i], "label:", labels[i])
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()
# Out:
# coordinate: [148.    0.   33.6   1. ] label: 2
# coordinate: [85.   0.  26.6  0. ] label: 2
# coordinate: [183.    0.   23.3   1. ] label: 2
# coordinate: [89.  94.  28.1  0. ] label: 0
# coordinate: [137.  168.   43.1   1. ] label: 0
# coordinate: [116.    0.   25.6   0. ] label: 2
# coordinate: [78. 88. 31.  1.] label: 0
# coordinate: [115.    0.   35.3   0. ] label: 2
# coordinate: [197.  543.   30.5   1. ] label: 1
# coordinate: [125.   0.   0.   1.] label: 2
# coordinate: [110.    0.   37.6   0. ] label: 2
# coordinate: [168.   0.  38.   1.] label: 2
# coordinate: [139.    0.   27.1   0. ] label: 2
# coordinate: [189.  846.   30.1   1. ] label: 1
# coordinate: [166.  175.   25.8   1. ] label: 0
# coordinate: [100.   0.  30.   1.] label: 2
# coordinate: [118.  230.   29.3   1. ] label: 3
# coordinate: [107.    0.   24.6   1. ] label: 2
# coordinate: [103.   83.   48.8   0. ] label: 0
# coordinate: [115.   96.   32.4   1. ] label: 0
# ...

# %%
predict = kmeans.predict(X)
data['cluster'] = predict
pd.plotting.parallel_coordinates(data, 'cluster')
